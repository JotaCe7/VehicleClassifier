# %% [markdown]
# # Vehicle Classification Report on Cropped dataset

# %%
import os

from sklearn.metrics import accuracy_score, classification_report

from utils import utils
from models import resnet_50

# %% [markdown]
# In this first section are shown some results obtained training our model with cropped data set, applying removing background.
#
# Weights were initialized with our previous fine tunning results.

# %% [markdown]
# ## TEST #1

# %% [markdown]
# For this test, all previous parameters from last train were kept.Only a learning rate variation was chosen to be less drastin (from 0.7 to 0.5), increased the patience and cooldown.
#
# ![exp_3 training](resources/exp_3_train.PNG "Training results from experiment 3")
#
# A validation accuracy of 0.68 was obtained at epoch 97.
#
# ![exp_3 acc](resources/exp_3_acc.PNG "Accuracy vs epoch - experiment 3")
# ![exp_3 loss](resources/exp_3_loss.PNG "Loss vs epoch - experiment 3")
#
# There is a better accuracy than training with original imeages and also less overfiting

# %% [markdown]
# ### Configuration file

# %%
CONFIG_YML = "../experiments/exp_3/config.yml"
WEIGHTS = "../experiments/exp_3/model.97-0.6800.h5"
config = utils.load_config(CONFIG_YML)
config
# Out:
# {'seed': 123,
#  'data': {'directory': '/home/app/src/data/car_ims_v2/train',
#   'labels': 'inferred',
#   'label_mode': 'categorical',
#   'validation_split': 0.2,
#   'image_size': [224, 224],
#   'batch_size': 32},
#  'model': {'weights': 'imagenet',
#   'input_shape': [224, 224, 3],
#   'classes': 196,
#   'dropout_rate': 0.5,
#   'data_aug_layer': {'random_flip': {'mode': 'horizontal'},
#    'random_rotation': {'factor': 0.3},
#    'random_zoom': {'height_factor': 0.2, 'width_factor': 0.2}},
#   'regularizers': {'kernel_regularizer': {'L2': {'l2': 0.001}},
#    'activity_regularizer': {'L2': {'l2': 0.001}}},
#   'output_regularizer': {'kernel_regularizer': {'L2': {'l2': 0.001}}},
#   'n_dense_layers': 2,
#   'n_unfreeze_layers': 8,
#   'trainable': True},
#  'compile': {'optimizer': {'adam': {'learning_rate': 0.0001}},
#   'loss': 'categorical_crossentropy',
#   'metrics': ['accuracy']},
#  'fit': {'epochs': 100,
#   'callbacks': {'model_checkpoint': {'filepath': '/home/app/src/experiments/exp_3/model.{epoch:02d}-{val_accuracy:.4f}.h5',
#     'save_best_only': False},
#    'tensor_board': {'log_dir': '/home/app/src/experiments/exp_3/logs'},
#    'reduce_on_plateau': {'monitor': 'val_accuracy',
#     'factor': 0.5,
#     'patience': 10,
#     'verbose': 0,
#     'mode': 'auto',
#     'min_delta': 0.005,
#     'cooldown': 5,
#     'min_lr': 0}}}}

# %%
# Infer the class names and also load the corresponding testing dataset.

MODEL_CLASSES = utils.get_class_names(config)

if len(MODEL_CLASSES) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your data!"
    )

_dirname, _ = os.path.split(config['data']['directory'])
TEST_FOLDER = os.path.join(_dirname, 'test')

if not os.path.exists(TEST_FOLDER):
    raise ValueError("'test' folder not found!")
    
if len(os.listdir(TEST_FOLDER)) != config['model']['classes']:
    raise ValueError(
        "Number of classes doesn't match between your model "
        "and your testing dataset!"
    )
    
if set(os.listdir(TEST_FOLDER)) != set(MODEL_CLASSES):
    raise ValueError(
        "The name of the subfolders inside your test set "
        "doesn't match with the model classes!"
    )

# %% [markdown]
# ### Loading the model

# %%
cnn_model = resnet_50.create_model(weights=WEIGHTS, trainable=False)
print(cnn_model.summary())
# Out:
# 2022-11-22 14:19:24.848177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:24.857960: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:24.858528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:24.860091: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-22 14:19:24.860558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:24.861030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:24.861473: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:25.980400: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:25.980905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:25.981360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:19:25.981762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2296 MB memory:  -> device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 196)               100548
#
# =================================================================
# Total params: 24,737,348
# Trainable params: 0
# Non-trainable params: 24,737,348
# _________________________________________________________________
# None

# %% [markdown]
# ### Get predictions from testing dataset

# %%
#     Get model predictions and the corresponding true labels
#     so we can measure the accuracy

predictions, labels = utils.predict_from_folder(
    folder=TEST_FOLDER, 
    model=cnn_model, 
    input_size=config["data"]["image_size"], 
    class_names=MODEL_CLASSES,
)

if len(predictions) != len(labels):
    raise ValueError(
        "The lenght of predictions and labels lists doesn't match!"
    )

if not isinstance(predictions[0], str):
    raise ValueError(
        "Model predictions should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )

if not isinstance(labels[0], str):
    raise ValueError(
        "Ground true labels should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )
# Out:
# 2022-11-22 14:19:39.522235: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8200
# 2022-11-22 14:19:39.988702: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-22 14:19:39.989337: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-22 14:19:39.989408: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-22 14:19:39.990060: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-22 14:19:39.990210: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-11-22 14:19:41.454154: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-11-22 14:19:41.492965: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.

# %%
print(classification_report(y_true=labels, y_pred=predictions))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             AM General Hummer SUV 2000       0.79      0.93      0.85        44
#                              Acura Integra Type R 2001       0.75      0.48      0.58        44
#                                    Acura RL Sedan 2012       0.40      0.12      0.19        32
#                                    Acura TL Sedan 2012       0.62      0.72      0.67        43
#                                   Acura TL Type-S 2008       0.62      0.60      0.61        42
#                                   Acura TSX Sedan 2012       0.60      0.30      0.40        40
#                               Acura ZDX Hatchback 2012       0.56      0.69      0.62        39
#               Aston Martin V8 Vantage Convertible 2012       0.40      0.42      0.41        45
#                     Aston Martin V8 Vantage Coupe 2012       0.37      0.27      0.31        41
#                   Aston Martin Virage Convertible 2012       0.77      0.61      0.68        33
#                         Aston Martin Virage Coupe 2012       0.78      0.74      0.76        38
#                                    Audi 100 Sedan 1994       0.62      0.53      0.57        40
#                                    Audi 100 Wagon 1994       0.78      0.43      0.55        42
#                                     Audi A5 Coupe 2012       0.45      0.71      0.55        41
#                                     Audi R8 Coupe 2012       0.77      0.47      0.58        43
#                             Audi RS 4 Convertible 2008       0.63      0.72      0.68        36
#                                     Audi S4 Sedan 2007       0.36      0.62      0.46        45
#                                     Audi S4 Sedan 2012       0.17      0.13      0.15        39
#                               Audi S5 Convertible 2012       0.75      0.43      0.55        42
#                                     Audi S5 Coupe 2012       0.36      0.24      0.29        42
#                                     Audi S6 Sedan 2011       0.79      0.67      0.73        46
#                                 Audi TT Hatchback 2011       0.55      0.42      0.48        40
#                                  Audi TT RS Coupe 2012       0.56      0.69      0.62        39
#                                    Audi TTS Coupe 2012       0.46      0.43      0.44        42
#                                     Audi V8 Sedan 1994       0.39      0.30      0.34        43
#                          BMW 1 Series Convertible 2012       0.68      0.77      0.72        35
#                                BMW 1 Series Coupe 2012       0.65      0.59      0.62        41
#                                BMW 3 Series Sedan 2012       0.67      0.43      0.52        42
#                                BMW 3 Series Wagon 2012       0.93      0.61      0.74        41
#                          BMW 6 Series Convertible 2007       0.58      0.25      0.35        44
#                          BMW ActiveHybrid 5 Sedan 2012       0.94      0.44      0.60        34
#                                      BMW M3 Coupe 2012       0.76      0.57      0.65        44
#                                      BMW M5 Sedan 2010       0.61      0.46      0.53        41
#                                BMW M6 Convertible 2010       0.39      0.66      0.49        41
#                                        BMW X3 SUV 2012       0.87      0.68      0.76        38
#                                        BMW X5 SUV 2007       0.71      0.66      0.68        41
#                                        BMW X6 SUV 2012       0.88      0.50      0.64        42
#                                BMW Z4 Convertible 2012       0.73      0.28      0.40        40
#                              Bentley Arnage Sedan 2009       0.51      0.69      0.59        39
#             Bentley Continental Flying Spur Sedan 2007       0.59      0.39      0.47        44
#                      Bentley Continental GT Coupe 2007       0.39      0.33      0.36        46
#                      Bentley Continental GT Coupe 2012       0.47      0.59      0.52        34
# Bentley Continental Supersports Conv. Convertible 2012       0.87      0.72      0.79        36
#                            Bentley Mulsanne Sedan 2011       0.67      0.63      0.65        35
#                   Bugatti Veyron 16.4 Convertible 2009       0.72      0.72      0.72        32
#                         Bugatti Veyron 16.4 Coupe 2009       0.78      0.58      0.67        43
#                                 Buick Enclave SUV 2012       0.65      0.86      0.74        42
#                                 Buick Rainier SUV 2007       0.79      0.45      0.58        42
#                                    Buick Regal GS 2012       0.65      0.63      0.64        35
#                                Buick Verano Sedan 2012       0.86      0.81      0.83        37
#                              Cadillac CTS-V Sedan 2012       0.57      0.67      0.62        43
#                    Cadillac Escalade EXT Crew Cab 2007       0.72      0.77      0.75        44
#                                  Cadillac SRX SUV 2012       0.68      0.63      0.66        41
#                      Chevrolet Avalanche Crew Cab 2012       0.42      0.56      0.48        45
#                      Chevrolet Camaro Convertible 2012       0.83      0.45      0.59        44
#                               Chevrolet Cobalt SS 2010       0.53      0.66      0.59        41
#                    Chevrolet Corvette Convertible 2012       0.62      0.62      0.62        39
#        Chevrolet Corvette Ron Fellows Edition Z06 2007       0.64      0.68      0.66        37
#                            Chevrolet Corvette ZR1 2012       0.77      0.52      0.62        46
#                       Chevrolet Express Cargo Van 2007       0.37      0.38      0.37        29
#                             Chevrolet Express Van 2007       0.47      0.26      0.33        35
#                                  Chevrolet HHR SS 2010       0.93      0.72      0.81        36
#                            Chevrolet Impala Sedan 2007       0.53      0.47      0.49        43
#                     Chevrolet Malibu Hybrid Sedan 2010       0.43      0.68      0.53        38
#                            Chevrolet Malibu Sedan 2007       0.64      0.41      0.50        44
#                       Chevrolet Monte Carlo Coupe 2007       0.74      0.64      0.69        45
#     Chevrolet Silverado 1500 Classic Extended Cab 2007       0.90      0.62      0.73        42
#             Chevrolet Silverado 1500 Extended Cab 2012       0.46      0.37      0.41        43
#          Chevrolet Silverado 1500 Hybrid Crew Cab 2012       0.53      0.47      0.50        40
#              Chevrolet Silverado 1500 Regular Cab 2012       0.46      0.70      0.55        44
#            Chevrolet Silverado 2500HD Regular Cab 2012       0.52      0.42      0.46        38
#                             Chevrolet Sonic Sedan 2012       0.31      0.80      0.45        44
#                        Chevrolet Tahoe Hybrid SUV 2012       0.70      0.43      0.53        37
#                          Chevrolet TrailBlazer SS 2009       0.73      0.60      0.66        40
#                            Chevrolet Traverse SUV 2012       0.69      0.70      0.70        44
#                                Chrysler 300 SRT-8 2010       0.48      0.69      0.56        48
#                                Chrysler Aspen SUV 2009       0.71      0.67      0.69        43
#                    Chrysler Crossfire Convertible 2008       0.82      0.74      0.78        43
#                   Chrysler PT Cruiser Convertible 2008       0.89      0.87      0.88        45
#                      Chrysler Sebring Convertible 2010       0.91      0.53      0.67        40
#                 Chrysler Town and Country Minivan 2012       0.88      0.62      0.73        37
#                               Daewoo Nubira Wagon 2002       1.00      0.31      0.47        45
#                               Dodge Caliber Wagon 2007       0.53      0.79      0.63        42
#                               Dodge Caliber Wagon 2012       0.42      0.38      0.39        40
#                             Dodge Caravan Minivan 1997       0.76      0.79      0.77        43
#                             Dodge Challenger SRT8 2011       0.78      0.74      0.76        39
#                               Dodge Charger SRT-8 2009       0.37      0.40      0.39        42
#                               Dodge Charger Sedan 2012       0.45      0.61      0.52        41
#                             Dodge Dakota Club Cab 2007       0.67      0.58      0.62        38
#                             Dodge Dakota Crew Cab 2010       0.60      0.63      0.62        41
#                                 Dodge Durango SUV 2007       0.54      0.67      0.59        45
#                                 Dodge Durango SUV 2012       0.70      0.74      0.72        43
#                                 Dodge Journey SUV 2012       0.59      0.82      0.69        44
#                                Dodge Magnum Wagon 2008       0.34      0.80      0.48        40
#                    Dodge Ram Pickup 3500 Crew Cab 2010       0.62      0.67      0.64        42
#                    Dodge Ram Pickup 3500 Quad Cab 2009       0.67      0.45      0.54        44
#                          Dodge Sprinter Cargo Van 2009       0.81      0.54      0.65        39
#                             Eagle Talon Hatchback 1998       0.64      0.46      0.53        46
#                                   FIAT 500 Abarth 2012       0.96      0.89      0.92        27
#                              FIAT 500 Convertible 2012       0.96      0.70      0.81        33
#                    Ferrari 458 Italia Convertible 2012       0.60      0.46      0.52        39
#                          Ferrari 458 Italia Coupe 2012       0.58      0.52      0.55        42
#                    Ferrari California Convertible 2012       0.63      0.79      0.70        39
#                                  Ferrari FF Coupe 2012       0.69      0.69      0.69        42
#                                Fisker Karma Sedan 2012       0.73      0.70      0.71        43
#                           Ford E-Series Wagon Van 2012       0.86      0.97      0.91        37
#                                     Ford Edge SUV 2012       0.75      0.56      0.64        43
#                            Ford Expedition EL SUV 2009       0.83      0.55      0.66        44
#                            Ford F-150 Regular Cab 2007       0.54      0.67      0.59        45
#                            Ford F-150 Regular Cab 2012       0.63      0.76      0.69        42
#                    Ford F-450 Super Duty Crew Cab 2012       0.87      0.83      0.85        41
#                                 Ford Fiesta Sedan 2012       0.88      0.52      0.66        42
#                                  Ford Focus Sedan 2007       0.63      0.58      0.60        45
#                             Ford Freestar Minivan 2007       0.91      0.66      0.76        44
#                                     Ford GT Coupe 2006       0.37      0.78      0.50        45
#                          Ford Mustang Convertible 2007       0.52      0.66      0.58        44
#                              Ford Ranger SuperCab 2011       0.65      0.86      0.74        42
#                                    GMC Acadia SUV 2012       0.63      0.70      0.67        44
#                           GMC Canyon Extended Cab 2012       0.57      0.70      0.63        40
#                                    GMC Savana Van 2012       0.69      0.75      0.72        68
#                                   GMC Terrain SUV 2012       0.67      0.73      0.70        41
#                              GMC Yukon Hybrid SUV 2012       0.83      0.60      0.69        42
#                             Geo Metro Convertible 1993       0.66      0.66      0.66        44
#                            HUMMER H2 SUT Crew Cab 2009       0.75      0.70      0.72        43
#                               HUMMER H3T Crew Cab 2010       0.69      0.79      0.74        39
#                                Honda Accord Coupe 2012       0.81      0.33      0.47        39
#                                Honda Accord Sedan 2012       0.79      0.29      0.42        38
#                             Honda Odyssey Minivan 2007       0.68      0.66      0.67        41
#                             Honda Odyssey Minivan 2012       0.67      0.67      0.67        42
#                              Hyundai Accent Sedan 2012       0.83      0.21      0.33        24
#                               Hyundai Azera Sedan 2012       0.45      0.76      0.57        42
#                             Hyundai Elantra Sedan 2007       0.83      0.71      0.77        42
#                 Hyundai Elantra Touring Hatchback 2012       0.77      0.48      0.59        42
#                             Hyundai Genesis Sedan 2012       0.75      0.84      0.79        43
#                              Hyundai Santa Fe SUV 2012       1.00      0.36      0.53        42
#                       Hyundai Sonata Hybrid Sedan 2012       0.76      0.76      0.76        33
#                              Hyundai Sonata Sedan 2012       0.89      0.44      0.59        39
#                                Hyundai Tucson SUV 2012       0.82      0.72      0.77        43
#                        Hyundai Veloster Hatchback 2012       0.75      0.73      0.74        41
#                              Hyundai Veracruz SUV 2012       0.45      0.55      0.49        42
#                              Infiniti G Coupe IPL 2012       1.00      0.38      0.55        34
#                                 Infiniti QX56 SUV 2011       0.86      0.38      0.52        32
#                                Isuzu Ascender SUV 2008       0.87      0.50      0.63        40
#                                     Jaguar XK XKR 2012       0.51      0.74      0.60        46
#                                  Jeep Compass SUV 2012       0.50      0.81      0.62        42
#                           Jeep Grand Cherokee SUV 2012       0.85      0.49      0.62        45
#                                  Jeep Liberty SUV 2012       0.40      0.75      0.52        44
#                                  Jeep Patriot SUV 2012       0.55      0.89      0.68        44
#                                 Jeep Wrangler SUV 2012       0.89      0.93      0.91        43
#                       Lamborghini Aventador Coupe 2012       0.81      0.67      0.73        43
#                          Lamborghini Diablo Coupe 2001       0.68      0.89      0.77        44
#        Lamborghini Gallardo LP 570-4 Superleggera 2012       0.96      0.63      0.76        35
#                        Lamborghini Reventon Coupe 2008       0.70      0.92      0.80        36
#                                Land Rover LR2 SUV 2012       0.63      0.62      0.63        42
#                        Land Rover Range Rover SUV 2012       0.67      0.83      0.74        42
#                            Lincoln Town Car Sedan 2011       0.89      0.64      0.75        39
#                  MINI Cooper Roadster Convertible 2012       0.97      0.89      0.93        36
#                     Maybach Landaulet Convertible 2012       0.70      0.72      0.71        29
#                                 Mazda Tribute SUV 2011       0.62      0.64      0.63        36
#                             McLaren MP4-12C Coupe 2012       0.79      0.84      0.81        44
#               Mercedes-Benz 300-Class Convertible 1993       0.63      0.69      0.66        48
#                       Mercedes-Benz C-Class Sedan 2012       0.72      0.29      0.41        45
#                       Mercedes-Benz E-Class Sedan 2012       0.25      0.65      0.37        43
#                       Mercedes-Benz S-Class Sedan 2012       0.92      0.27      0.42        44
#                      Mercedes-Benz SL-Class Coupe 2009       0.93      0.72      0.81        36
#                        Mercedes-Benz Sprinter Van 2012       0.60      0.95      0.74        41
#                           Mitsubishi Lancer Sedan 2012       0.35      0.74      0.48        47
#                                Nissan 240SX Coupe 1998       0.52      0.78      0.63        46
#                             Nissan Juke Hatchback 2012       0.68      0.91      0.78        44
#                             Nissan Leaf Hatchback 2012       0.83      0.95      0.89        42
#                           Nissan NV Passenger Van 2012       0.74      0.97      0.84        38
#                               Plymouth Neon Coupe 1999       0.73      0.73      0.73        44
#                            Porsche Panamera Sedan 2012       0.43      0.70      0.54        43
#                         Ram C-V Cargo Van Minivan 2012       0.72      0.76      0.74        41
#                           Rolls-Royce Ghost Sedan 2012       0.56      0.74      0.64        38
#    Rolls-Royce Phantom Drophead Coupe Convertible 2012       0.62      0.70      0.66        30
#                         Rolls-Royce Phantom Sedan 2012       0.67      0.55      0.60        44
#                                Scion xD Hatchback 2012       0.70      0.68      0.69        41
#                             Spyker C8 Convertible 2009       0.72      0.80      0.76        45
#                                   Spyker C8 Coupe 2009       0.73      0.45      0.56        42
#                                Suzuki Aerio Sedan 2007       0.73      0.42      0.53        38
#                              Suzuki Kizashi Sedan 2012       0.51      0.70      0.59        46
#                              Suzuki SX4 Hatchback 2012       0.37      0.76      0.50        42
#                                  Suzuki SX4 Sedan 2012       0.50      0.23      0.31        40
#                               Tesla Model S Sedan 2012       0.85      0.74      0.79        38
#                                Toyota 4Runner SUV 2012       0.78      0.88      0.82        40
#                                Toyota Camry Sedan 2012       0.51      0.60      0.55        43
#                              Toyota Corolla Sedan 2012       0.71      0.23      0.35        43
#                                Toyota Sequoia SUV 2012       0.95      0.55      0.70        38
#                       Volkswagen Beetle Hatchback 2012       0.69      0.90      0.78        42
#                         Volkswagen Golf Hatchback 1991       0.47      0.98      0.64        46
#                         Volkswagen Golf Hatchback 2012       0.88      0.49      0.63        43
#                                   Volvo 240 Sedan 1993       0.54      0.96      0.69        45
#                               Volvo C30 Hatchback 2012       0.70      0.80      0.75        41
#                                    Volvo XC90 SUV 2007       0.62      0.47      0.53        43
#                          smart fortwo Convertible 2012       1.00      0.80      0.89        40
#
#                                               accuracy                           0.62      8041
#                                              macro avg       0.67      0.62      0.62      8041
#                                           weighted avg       0.67      0.62      0.62      8041

# %%
acc = accuracy_score(y_true=labels, y_pred=predictions)

print(f"Your model accuracy is {acc:.4f}!")

if acc < .3:
    raise ValueError("Your model accuracy is too low :(\nYou can do it better! :)")
# Out:
# Your model accuracy is 0.6227!

# %% [markdown]
# ## Test 2

# %% [markdown]
# For this test a fine-tuning was performed starting from the previous weights
#
# A maximum validation accuracy of 0.8446 was obtained at epoch 52; and 0.8329 at the last epoch 75
#
# ![exp_4 acc](resources/exp_4_acc.PNG "Accuracy vs epoch - experiment 4")
# ![exp_3 loss](resources/exp_3_loss.PNG "Loss vs epoch - experiment 3")
#
# Model is overfitting again (train accuracy very close to 1),  similar to the model without cropped images.

# %%
CONFIG_YML_RETRAIN = "../experiments/exp_4/config.yml"
WEIGHTS_RETRAIN = "../experiments/exp_4/model.75-0.8329.h5"
config_retrain = utils.load_config(CONFIG_YML_RETRAIN)
config_retrain
# Out:
# {'seed': 123,
#  'data': {'directory': '/home/app/src/data/car_ims_v2/train',
#   'labels': 'inferred',
#   'label_mode': 'categorical',
#   'validation_split': 0.2,
#   'image_size': [224, 224],
#   'batch_size': 32},
#  'model': {'weights': '/home/app/src/experiments/exp_3/model.97-0.6800.h5',
#   'input_shape': [224, 224, 3],
#   'classes': 196,
#   'dropout_rate': 0.5,
#   'data_aug_layer': {'random_flip': {'mode': 'horizontal'},
#    'random_rotation': {'factor': 0.3},
#    'random_zoom': {'height_factor': 0.2, 'width_factor': 0.2}},
#   'regularizers': {'kernel_regularizer': {'L2': {'l2': 0.001}},
#    'activity_regularizer': {'L2': {'l2': 0.001}}},
#   'output_regularizer': {'kernel_regularizer': {'L2': {'l2': 0.001}}},
#   'n_dense_layers': 2,
#   'n_unfreeze_layers': 8,
#   'trainable': True},
#  'compile': {'optimizer': {'adam': {'learning_rate': 0.0001}},
#   'loss': 'categorical_crossentropy',
#   'metrics': ['accuracy']},
#  'fit': {'epochs': 100,
#   'callbacks': {'model_checkpoint': {'filepath': '/home/app/src/experiments/exp_4/model.{epoch:02d}-{val_accuracy:.4f}.h5',
#     'save_best_only': False},
#    'tensor_board': {'log_dir': '/home/app/src/experiments/exp_4/logs'},
#    'reduce_on_plateau': {'monitor': 'val_accuracy',
#     'factor': 0.5,
#     'patience': 10,
#     'verbose': 0,
#     'mode': 'auto',
#     'min_delta': 0.005,
#     'cooldown': 5,
#     'min_lr': 0}}}}

# %%
cnn_model_retrain = resnet_50.create_model(weights=WEIGHTS_RETRAIN, trainable=False)
print(cnn_model_retrain.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 196)               100548
#
# =================================================================
# Total params: 24,737,348
# Trainable params: 0
# Non-trainable params: 24,737,348
# _________________________________________________________________
# None

# %%
#     Get model predictions and the corresponding true labels
#     so we can measure the accuracy

predictions_retrain, labels_retrain = utils.predict_from_folder(
    folder=TEST_FOLDER, 
    model=cnn_model_retrain, 
    input_size=config["data"]["image_size"], 
    class_names=MODEL_CLASSES,
)

if len(predictions_retrain) != len(labels_retrain):
    raise ValueError(
        "The lenght of predictions and labels lists doesn't match!"
    )

if not isinstance(predictions_retrain[0], str):
    raise ValueError(
        "Model predictions should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )

if not isinstance(labels_retrain[0], str):
    raise ValueError(
        "Ground true labels should be represented as string. E.g: 'Acura RL Sedan 2012'"
    )

# %%
print(classification_report(y_true=labels_retrain, y_pred=predictions_retrain))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             AM General Hummer SUV 2000       0.71      0.89      0.79        44
#                              Acura Integra Type R 2001       0.93      0.91      0.92        44
#                                    Acura RL Sedan 2012       0.81      0.69      0.75        32
#                                    Acura TL Sedan 2012       0.80      0.95      0.87        43
#                                   Acura TL Type-S 2008       0.93      0.98      0.95        42
#                                   Acura TSX Sedan 2012       0.84      0.68      0.75        40
#                               Acura ZDX Hatchback 2012       0.88      0.90      0.89        39
#               Aston Martin V8 Vantage Convertible 2012       0.54      0.82      0.65        45
#                     Aston Martin V8 Vantage Coupe 2012       0.77      0.56      0.65        41
#                   Aston Martin Virage Convertible 2012       0.95      0.61      0.74        33
#                         Aston Martin Virage Coupe 2012       0.87      0.89      0.88        38
#                                    Audi 100 Sedan 1994       0.51      0.65      0.57        40
#                                    Audi 100 Wagon 1994       0.73      0.52      0.61        42
#                                     Audi A5 Coupe 2012       0.65      0.78      0.71        41
#                                     Audi R8 Coupe 2012       0.88      0.88      0.88        43
#                             Audi RS 4 Convertible 2008       0.94      0.81      0.87        36
#                                     Audi S4 Sedan 2007       0.82      0.73      0.78        45
#                                     Audi S4 Sedan 2012       0.59      0.51      0.55        39
#                               Audi S5 Convertible 2012       0.94      0.69      0.79        42
#                                     Audi S5 Coupe 2012       0.57      0.60      0.58        42
#                                     Audi S6 Sedan 2011       0.84      0.83      0.84        46
#                                 Audi TT Hatchback 2011       0.57      0.50      0.53        40
#                                  Audi TT RS Coupe 2012       0.72      0.59      0.65        39
#                                    Audi TTS Coupe 2012       0.45      0.71      0.56        42
#                                     Audi V8 Sedan 1994       0.69      0.63      0.66        43
#                          BMW 1 Series Convertible 2012       0.94      0.86      0.90        35
#                                BMW 1 Series Coupe 2012       0.89      0.83      0.86        41
#                                BMW 3 Series Sedan 2012       0.87      0.81      0.84        42
#                                BMW 3 Series Wagon 2012       0.87      0.83      0.85        41
#                          BMW 6 Series Convertible 2007       0.70      0.64      0.67        44
#                          BMW ActiveHybrid 5 Sedan 2012       0.91      0.91      0.91        34
#                                      BMW M3 Coupe 2012       0.84      0.86      0.85        44
#                                      BMW M5 Sedan 2010       0.89      0.80      0.85        41
#                                BMW M6 Convertible 2010       0.58      0.73      0.65        41
#                                        BMW X3 SUV 2012       0.95      0.95      0.95        38
#                                        BMW X5 SUV 2007       0.90      0.93      0.92        41
#                                        BMW X6 SUV 2012       1.00      0.79      0.88        42
#                                BMW Z4 Convertible 2012       0.88      0.72      0.79        40
#                              Bentley Arnage Sedan 2009       0.77      0.92      0.84        39
#             Bentley Continental Flying Spur Sedan 2007       0.80      0.45      0.58        44
#                      Bentley Continental GT Coupe 2007       0.49      0.78      0.61        46
#                      Bentley Continental GT Coupe 2012       0.67      0.65      0.66        34
# Bentley Continental Supersports Conv. Convertible 2012       0.90      0.75      0.82        36
#                            Bentley Mulsanne Sedan 2011       0.96      0.74      0.84        35
#                   Bugatti Veyron 16.4 Convertible 2009       0.77      0.72      0.74        32
#                         Bugatti Veyron 16.4 Coupe 2009       0.85      0.81      0.83        43
#                                 Buick Enclave SUV 2012       0.87      0.98      0.92        42
#                                 Buick Rainier SUV 2007       1.00      0.83      0.91        42
#                                    Buick Regal GS 2012       0.94      0.91      0.93        35
#                                Buick Verano Sedan 2012       0.92      0.97      0.95        37
#                              Cadillac CTS-V Sedan 2012       0.89      0.98      0.93        43
#                    Cadillac Escalade EXT Crew Cab 2007       0.81      0.89      0.85        44
#                                  Cadillac SRX SUV 2012       1.00      0.88      0.94        41
#                      Chevrolet Avalanche Crew Cab 2012       0.67      0.89      0.76        45
#                      Chevrolet Camaro Convertible 2012       0.97      0.73      0.83        44
#                               Chevrolet Cobalt SS 2010       0.86      0.90      0.88        41
#                    Chevrolet Corvette Convertible 2012       0.73      0.77      0.75        39
#        Chevrolet Corvette Ron Fellows Edition Z06 2007       0.83      0.81      0.82        37
#                            Chevrolet Corvette ZR1 2012       0.78      0.85      0.81        46
#                       Chevrolet Express Cargo Van 2007       0.40      0.55      0.46        29
#                             Chevrolet Express Van 2007       0.48      0.37      0.42        35
#                                  Chevrolet HHR SS 2010       0.97      0.92      0.94        36
#                            Chevrolet Impala Sedan 2007       0.81      0.88      0.84        43
#                     Chevrolet Malibu Hybrid Sedan 2010       0.83      0.89      0.86        38
#                            Chevrolet Malibu Sedan 2007       0.94      0.75      0.84        44
#                       Chevrolet Monte Carlo Coupe 2007       0.83      0.84      0.84        45
#     Chevrolet Silverado 1500 Classic Extended Cab 2007       0.93      0.90      0.92        42
#             Chevrolet Silverado 1500 Extended Cab 2012       0.83      0.56      0.67        43
#          Chevrolet Silverado 1500 Hybrid Crew Cab 2012       0.60      0.75      0.67        40
#              Chevrolet Silverado 1500 Regular Cab 2012       0.58      0.68      0.62        44
#            Chevrolet Silverado 2500HD Regular Cab 2012       0.60      0.63      0.62        38
#                             Chevrolet Sonic Sedan 2012       0.78      0.98      0.87        44
#                        Chevrolet Tahoe Hybrid SUV 2012       0.72      0.49      0.58        37
#                          Chevrolet TrailBlazer SS 2009       0.95      0.93      0.94        40
#                            Chevrolet Traverse SUV 2012       0.77      0.91      0.83        44
#                                Chrysler 300 SRT-8 2010       0.90      0.79      0.84        48
#                                Chrysler Aspen SUV 2009       0.80      0.93      0.86        43
#                    Chrysler Crossfire Convertible 2008       0.97      0.88      0.93        43
#                   Chrysler PT Cruiser Convertible 2008       1.00      0.93      0.97        45
#                      Chrysler Sebring Convertible 2010       0.92      0.85      0.88        40
#                 Chrysler Town and Country Minivan 2012       0.94      0.81      0.87        37
#                               Daewoo Nubira Wagon 2002       0.92      0.80      0.86        45
#                               Dodge Caliber Wagon 2007       0.74      0.62      0.68        42
#                               Dodge Caliber Wagon 2012       0.70      0.80      0.74        40
#                             Dodge Caravan Minivan 1997       0.98      0.98      0.98        43
#                             Dodge Challenger SRT8 2011       1.00      0.95      0.97        39
#                               Dodge Charger SRT-8 2009       0.91      0.74      0.82        42
#                               Dodge Charger Sedan 2012       0.75      0.95      0.84        41
#                             Dodge Dakota Club Cab 2007       0.88      0.92      0.90        38
#                             Dodge Dakota Crew Cab 2010       0.95      0.85      0.90        41
#                                 Dodge Durango SUV 2007       0.93      0.82      0.87        45
#                                 Dodge Durango SUV 2012       1.00      0.93      0.96        43
#                                 Dodge Journey SUV 2012       0.93      0.89      0.91        44
#                                Dodge Magnum Wagon 2008       0.81      0.85      0.83        40
#                    Dodge Ram Pickup 3500 Crew Cab 2010       0.97      0.88      0.93        42
#                    Dodge Ram Pickup 3500 Quad Cab 2009       0.88      0.84      0.86        44
#                          Dodge Sprinter Cargo Van 2009       0.83      0.74      0.78        39
#                             Eagle Talon Hatchback 1998       0.87      0.85      0.86        46
#                                   FIAT 500 Abarth 2012       1.00      0.96      0.98        27
#                              FIAT 500 Convertible 2012       0.93      0.85      0.89        33
#                    Ferrari 458 Italia Convertible 2012       0.70      0.79      0.75        39
#                          Ferrari 458 Italia Coupe 2012       0.68      0.64      0.66        42
#                    Ferrari California Convertible 2012       0.95      0.97      0.96        39
#                                  Ferrari FF Coupe 2012       1.00      0.86      0.92        42
#                                Fisker Karma Sedan 2012       0.91      0.98      0.94        43
#                           Ford E-Series Wagon Van 2012       0.86      0.97      0.91        37
#                                     Ford Edge SUV 2012       0.88      1.00      0.93        43
#                            Ford Expedition EL SUV 2009       0.95      0.93      0.94        44
#                            Ford F-150 Regular Cab 2007       0.91      0.93      0.92        45
#                            Ford F-150 Regular Cab 2012       0.95      0.93      0.94        42
#                    Ford F-450 Super Duty Crew Cab 2012       0.84      0.90      0.87        41
#                                 Ford Fiesta Sedan 2012       0.95      0.93      0.94        42
#                                  Ford Focus Sedan 2007       0.95      0.87      0.91        45
#                             Ford Freestar Minivan 2007       0.89      0.95      0.92        44
#                                     Ford GT Coupe 2006       0.76      0.87      0.81        45
#                          Ford Mustang Convertible 2007       0.79      0.95      0.87        44
#                              Ford Ranger SuperCab 2011       0.93      0.95      0.94        42
#                                    GMC Acadia SUV 2012       0.95      0.95      0.95        44
#                           GMC Canyon Extended Cab 2012       0.94      0.85      0.89        40
#                                    GMC Savana Van 2012       0.83      0.76      0.79        68
#                                   GMC Terrain SUV 2012       0.89      0.98      0.93        41
#                              GMC Yukon Hybrid SUV 2012       0.94      0.81      0.87        42
#                             Geo Metro Convertible 1993       0.90      0.82      0.86        44
#                            HUMMER H2 SUT Crew Cab 2009       0.90      0.84      0.87        43
#                               HUMMER H3T Crew Cab 2010       0.92      0.92      0.92        39
#                                Honda Accord Coupe 2012       1.00      0.85      0.92        39
#                                Honda Accord Sedan 2012       0.86      0.84      0.85        38
#                             Honda Odyssey Minivan 2007       1.00      0.88      0.94        41
#                             Honda Odyssey Minivan 2012       0.90      0.86      0.88        42
#                              Hyundai Accent Sedan 2012       0.91      0.83      0.87        24
#                               Hyundai Azera Sedan 2012       0.73      0.83      0.78        42
#                             Hyundai Elantra Sedan 2007       0.97      0.79      0.87        42
#                 Hyundai Elantra Touring Hatchback 2012       0.93      0.95      0.94        42
#                             Hyundai Genesis Sedan 2012       0.93      0.95      0.94        43
#                              Hyundai Santa Fe SUV 2012       0.97      0.90      0.94        42
#                       Hyundai Sonata Hybrid Sedan 2012       0.84      0.94      0.89        33
#                              Hyundai Sonata Sedan 2012       0.94      0.87      0.91        39
#                                Hyundai Tucson SUV 2012       0.80      0.93      0.86        43
#                        Hyundai Veloster Hatchback 2012       0.87      0.80      0.84        41
#                              Hyundai Veracruz SUV 2012       0.78      0.90      0.84        42
#                              Infiniti G Coupe IPL 2012       1.00      0.79      0.89        34
#                                 Infiniti QX56 SUV 2011       0.97      0.94      0.95        32
#                                Isuzu Ascender SUV 2008       0.97      0.93      0.95        40
#                                     Jaguar XK XKR 2012       0.90      0.96      0.93        46
#                                  Jeep Compass SUV 2012       0.69      0.88      0.77        42
#                           Jeep Grand Cherokee SUV 2012       0.89      0.87      0.88        45
#                                  Jeep Liberty SUV 2012       0.91      0.89      0.90        44
#                                  Jeep Patriot SUV 2012       0.87      0.89      0.88        44
#                                 Jeep Wrangler SUV 2012       0.95      0.98      0.97        43
#                       Lamborghini Aventador Coupe 2012       0.81      0.70      0.75        43
#                          Lamborghini Diablo Coupe 2001       0.82      0.91      0.86        44
#        Lamborghini Gallardo LP 570-4 Superleggera 2012       0.93      0.80      0.86        35
#                        Lamborghini Reventon Coupe 2008       0.81      0.94      0.87        36
#                                Land Rover LR2 SUV 2012       0.93      0.95      0.94        42
#                        Land Rover Range Rover SUV 2012       0.91      0.98      0.94        42
#                            Lincoln Town Car Sedan 2011       0.92      0.90      0.91        39
#                  MINI Cooper Roadster Convertible 2012       0.80      0.97      0.88        36
#                     Maybach Landaulet Convertible 2012       0.92      0.83      0.87        29
#                                 Mazda Tribute SUV 2011       0.97      0.97      0.97        36
#                             McLaren MP4-12C Coupe 2012       0.91      0.95      0.93        44
#               Mercedes-Benz 300-Class Convertible 1993       0.78      0.94      0.85        48
#                       Mercedes-Benz C-Class Sedan 2012       0.98      0.89      0.93        45
#                       Mercedes-Benz E-Class Sedan 2012       0.62      1.00      0.77        43
#                       Mercedes-Benz S-Class Sedan 2012       0.97      0.77      0.86        44
#                      Mercedes-Benz SL-Class Coupe 2009       1.00      0.86      0.93        36
#                        Mercedes-Benz Sprinter Van 2012       0.81      0.95      0.88        41
#                           Mitsubishi Lancer Sedan 2012       0.85      0.83      0.84        47
#                                Nissan 240SX Coupe 1998       0.93      0.89      0.91        46
#                             Nissan Juke Hatchback 2012       0.64      0.95      0.76        44
#                             Nissan Leaf Hatchback 2012       0.95      0.98      0.96        42
#                           Nissan NV Passenger Van 2012       0.86      0.95      0.90        38
#                               Plymouth Neon Coupe 1999       0.88      0.98      0.92        44
#                            Porsche Panamera Sedan 2012       0.90      0.86      0.88        43
#                         Ram C-V Cargo Van Minivan 2012       0.89      0.80      0.85        41
#                           Rolls-Royce Ghost Sedan 2012       0.87      0.87      0.87        38
#    Rolls-Royce Phantom Drophead Coupe Convertible 2012       0.75      0.80      0.77        30
#                         Rolls-Royce Phantom Sedan 2012       0.89      0.75      0.81        44
#                                Scion xD Hatchback 2012       0.93      0.98      0.95        41
#                             Spyker C8 Convertible 2009       0.78      0.87      0.82        45
#                                   Spyker C8 Coupe 2009       0.90      0.64      0.75        42
#                                Suzuki Aerio Sedan 2007       0.88      0.74      0.80        38
#                              Suzuki Kizashi Sedan 2012       0.73      0.89      0.80        46
#                              Suzuki SX4 Hatchback 2012       0.84      0.90      0.87        42
#                                  Suzuki SX4 Sedan 2012       0.83      0.62      0.71        40
#                               Tesla Model S Sedan 2012       0.90      0.92      0.91        38
#                                Toyota 4Runner SUV 2012       0.93      0.97      0.95        40
#                                Toyota Camry Sedan 2012       0.79      0.88      0.84        43
#                              Toyota Corolla Sedan 2012       0.84      0.88      0.86        43
#                                Toyota Sequoia SUV 2012       1.00      0.87      0.93        38
#                       Volkswagen Beetle Hatchback 2012       0.93      0.95      0.94        42
#                         Volkswagen Golf Hatchback 1991       0.85      0.98      0.91        46
#                         Volkswagen Golf Hatchback 2012       0.94      0.72      0.82        43
#                                   Volvo 240 Sedan 1993       0.89      0.93      0.91        45
#                               Volvo C30 Hatchback 2012       0.92      0.88      0.90        41
#                                    Volvo XC90 SUV 2007       1.00      0.84      0.91        43
#                          smart fortwo Convertible 2012       0.95      0.90      0.92        40
#
#                                               accuracy                           0.84      8041
#                                              macro avg       0.85      0.84      0.84      8041
#                                           weighted avg       0.85      0.84      0.84      8041

# %%
acc = accuracy_score(y_true=labels_retrain, y_pred=predictions_retrain)

print(f"Your model accuracy is {acc:.4f}!")

if acc < .3:
    raise ValueError("Your model accuracy is too low :(\nYou can do it better! :)")
# Out:
# Your model accuracy is 0.8413!

# %% [markdown]
# ## Conclussion
#
# - As the dataset is well balanced, accuracy give as a good estimation of our model performance.
# - Removing the background from the images using detectron2 considetable improved the accuracy of our models.
# - Reducing overfiting was a very difficult task, increasing droup rate and regularization did not help to prevent it. Increasing them a lot made the model to not evenlearnfrom the dataset.
# - Even though we had much higher accuracy in training with respect to validation (overfitting), our models performed very similar in test set in comparisson of validation, which indicates robustness.
# - Experimenting with sgd optimizer instead of adam does not seem to have considerable impact. Playing around with different parameters and hhyperparametes along with sgdoptimizer are needed to have  fair comparisson.
# - Adding more layers on top of renet_50 model shows a high improvement with respect to adding only the output layer in the first train (starting from pre trainned imagenet weight). In the fine tunning step, similar results are obtained with more dense layers or without them.
# - Given the small dataset and the reduced amount of resources (hardware and time) quite good results were obtained.
